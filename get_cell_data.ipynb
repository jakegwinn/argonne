# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import tqdm
import os

import requests
from bs4 import BeautifulSoup

# %%
r = requests.get("https://www.cellosaurus.org/search?query=ACH-000219")

# %%
soup = BeautifulSoup(r.content, "lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="bioschema: https://bioschemas.org/" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#   <!-- automatically added by Apache -->
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <!-- automatically added by Apache -->
#   <script type="application/ld+json">
#    {
#             "@context": [ "https://schema.org/" ],
#             "@type": "Organization",
#             "url": "https://(www.)?cellosaurus.org",
#             "name": "Cellosaurus",
#             "logo": "https://(www.)?cellosaurus.org/images/cellosaurus/cellosaurus.png",
#             "memberof": {
#                 "@type": "NGO",
#                 "name": "SIB Swiss Institute of Bioinformatics",
#                 "url": "https://sib.swiss/"
#             },
#             "parentOrganization": {
#                 "@type": "Organization",
#                 "name": "Expasy",
# ...

# %%
s = soup.find_all("table")

# %%
cell = "ACH-000041"

# %%
cell_line = pd.read_html(f"https://www.cellosaurus.org/search?query={cell}")[0][0][0]

# %%
df = pd.read_html(f"https://www.cellosaurus.org/{cell_line}")

# %%
for x in df:
    if True in (x == "Sex of cell").any().unique():
        print(x)
# Out:
#                                       0  \
# 0                        Cell line name
# 1                              Synonyms
# 2                             Accession
# 3    Resource Identification Initiative
# 4                              Comments
# 5                   Sequence variations
# 6                       Genome ancestry
# 7                               Disease
# 8                     Species of origin
# 9                             Hierarchy
# 10                          Sex of cell
# 11                      Age at sampling
# 12                             Category
# 13                          STR profile
# 14                            Web pages
# 15                         Publications
# 16                     Cross-references
# 17    Cell line collections (Providers)
# 18        Cell line databases/resources
# 19          Anatomy/cell type resources
# 20          Biological sample resources
# 21           CRISP screens repositories
# ...

# %%
for x in df:
    print(True in (x == "Sex of cell").any().unique())
# Out:
# True
# False
# False
# False

# %%
[x for x in df if True in (x == "African").any().unique()]
# Out:
# [              Origin  % genome
#  0                NaN       NaN
#  1            African      1.21
#  2    Native American      0.02
#  3  East Asian, North      3.10
#  4  East Asian, South      0.00
#  5        South Asian      0.00
#  6    European, North     61.77
#  7    European, South     33.89]

# %%
print(df)
# Out:
# [                                      0  \
# 0                        Cell line name
# 1                              Synonyms
# 2                             Accession
# 3    Resource Identification Initiative
# 4                              Comments
# 5                   Sequence variations
# 6                       Genome ancestry
# 7                               Disease
# 8                     Species of origin
# 9                             Hierarchy
# 10                          Sex of cell
# 11                      Age at sampling
# 12                             Category
# 13                          STR profile
# 14                            Web pages
# 15                         Publications
# 16                     Cross-references
# 17    Cell line collections (Providers)
# 18        Cell line databases/resources
# 19          Anatomy/cell type resources
# 20          Biological sample resources
# 21           CRISP screens repositories
# ...

# %%
df[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/w_/tv9kwn955c59q5gycbr00lzh0000gn/T/ipykernel_79507/2439795984.py in <module>
# ----> 1 df[4]
#
# IndexError: list index out of range

# %%
race_df = [x for x in df if True in (x == "African").any().unique()]
meta_df = [x for x in df if True in (x == "Sex of cell").any().unique()]

r_df = race_df[0]
m_df = meta_df[0]

# %%
cells = ['ACH-000001',
 'ACH-000002',
 'ACH-000004',
 'ACH-000006',
 'ACH-000007',
 'ACH-000008',
 'ACH-000009',
 'ACH-000012',
 'ACH-000019',
 'ACH-000020',
 'ACH-000023',
 'ACH-000024',
 'ACH-000035',
 'ACH-000040',
    # print(cell)
    done_cells.append(cell)
    cell_line = pd.read_html(f"https://www.cellosaurus.org/search?query={cell}")[0][0][0]
    df = pd.read_html(f"https://www.cellosaurus.org/{cell_line}")
    
    race_df = [x for x in df if True in (x == "African").any().unique()]
    meta_df = [x for x in df if True in (x == "Cell line name").any().unique()]

    
    
    m_df = meta_df[0]



    if m_df[m_df[0] == "Disease"].empty:
        disease = "Not_specified"
    else:
        disease = m_df[m_df[0] == "Disease"].iloc[0][1]
        
    
    
    if m_df[m_df[0] == "Sex of cell"].empty:
       sex = "Not_specified"   
    else:
        sex = m_df[m_df[0] == "Sex of cell"].iloc[0][1]    
    
    
    
    
    if not m_df[m_df[0] == "Age at sampling"].empty:
        if not re.findall(r"\d+", (m_df[m_df[0] == "Age at sampling"].iloc[0][1])):
            age = np.nan

        else:
            age = int(re.findall(r"\d+", (m_df[m_df[0] == "Age at sampling"].iloc[0][1]))[0])
    else:
        age = np.nan

    
    # age = int(re.findall(r"\d+", (m_df[m_df[0] == "Age at sampling"].iloc[0][1]))[0])

    metadata["cell"].append(cell)
    metadata["disease"].append(disease)
    metadata["sex"].append(sex)
    metadata["age"].append(age)

    if len(race_df) != 0:
        r_df = race_df[0]
        for r in races:
            percent = r_df.pivot_table(columns="Origin", values="% genome")[r][0]
            metadata[r].append(percent)
    else:
        for r in races:
            # percent = r_df.pivot_table(columns="Origin", values="% genome")[r][0]
            metadata[r].append(np.nan)
# Out:
# 100%|██████████| 785/785 [34:25<00:00,  2.63s/it]

# %%
cell_df = pd.DataFrame(metadata)

# %%
def get_all_df_drug(drg, path):
    """Get all the locations of specified drug

    Args:
        drg (string): name of drug 
        path (string): path to all the tsv's

    Returns:
        pandas.Dataframe: a dataframe of all the tsv's about the specified drug
    """
    
    drug_loc = []
    for subdir, dirs, files in os.walk(path):
        for file in files:
            
            # Get file location and make dataframe 
            curr = os.path.join(subdir,file)
            d = pd.read_csv(curr, sep="\t")
            
            # Get metadata on file 
            fold_num = subdir.split("/")[-1]
            drug = d["Drug1"][0]
            job = subdir.split("/")[-2]
            
            # Check if drug in file is same as drg
            if drug == drg:
                drug_loc.append((job, fold_num))
            
    
    # Concatonate all dataframes of all of the tsv's of drg
    dfs = []
    for j,folder in drug_loc:

        file = os.path.join(os.path.join(os.path.join(path, j), folder), "predicted.tsv")

        df = pd.read_csv(file, sep="\t")
        dfs.append(df)

    df = pd.concat(dfs)
    return df

# %%
done_cells[-1]
# Out:
# 'ACH-000041'

# %%
wd = os.getcwd() 
path = os.path.join(os.path.join(wd, "data"), "TSVs")

# %%
df_988 = get_all_df_drug("Drug_736", path=path)

# %%
df_988
# Out:
#         AUC      Sample     Drug1  PredictedAUC  AUCError
# 0    0.4912  ACH-000001  Drug_736        0.9884    0.4972
# 1    0.2607  ACH-000002  Drug_736        0.9620    0.7013
# 2    0.6061  ACH-000004  Drug_736        0.9789    0.3728
# 3    0.4877  ACH-000006  Drug_736        0.9487    0.4610
# 4    0.4755  ACH-000007  Drug_736        0.9835    0.5080
# ..      ...         ...       ...           ...       ...
# 544  0.4936  ACH-001190  Drug_736        0.9803    0.4867
# 545  0.7583  ACH-001306  Drug_736        0.9829    0.2246
# 546  0.5376  ACH-001307  Drug_736        0.9762    0.4386
# 547  0.6033  ACH-001307  Drug_736        0.9786    0.3753
# 548  0.8100  ACH-001321  Drug_736        0.9596    0.1496
#
# [4392 rows x 5 columns]

# %%
df_988 = df_988.merge(cell_df, left_on="Sample", right_on="cell")
df_988
# Out:
#          AUC      Sample     Drug1  PredictedAUC  AUCError        cell  \
# 0     0.4912  ACH-000001  Drug_736        0.9884   0.49720  ACH-000001
# 1     0.4912  ACH-000001  Drug_736        0.9823   0.49110  ACH-000001
# 2     0.4912  ACH-000001  Drug_736        0.9575   0.46630  ACH-000001
# 3     0.4912  ACH-000001  Drug_736        0.9604   0.46920  ACH-000001
# 4     0.4912  ACH-000001  Drug_736        0.9801   0.48890  ACH-000001
# ...      ...         ...       ...           ...       ...         ...
# 4387  0.8100  ACH-001321  Drug_736        0.9504   0.14040  ACH-001321
# 4388  0.8100  ACH-001321  Drug_736        0.9663   0.15630  ACH-001321
# 4389  0.8100  ACH-001321  Drug_736        0.9515   0.14150  ACH-001321
# 4390  0.8100  ACH-001321  Drug_736        0.7471  -0.06291  ACH-001321
# 4391  0.8100  ACH-001321  Drug_736        0.9596   0.14960  ACH-001321
#
#                                                 disease   age     sex  \
# ...

# %%
(df_988
    .sort_values("AUCError", ascending=False)
    .groupby("disease")
    .describe()["AUCError"]
    .sort_values(["count"], ascending=False)
    
    # .head(50)
 )
# Out:
#                                                     count      mean       std  \
# disease
# Lung adenocarcinoma (NCIt: C3512)                   360.0  0.238221  0.194955
# Lung small cell carcinoma (NCIt: C4917) Small c...  280.0  0.335046  0.209857
# Colon adenocarcinoma (NCIt: C4349)                  160.0  0.283974  0.175820
# Esophageal squamous cell carcinoma (NCIt: C4024...  152.0  0.316536  0.196847
# Glioblastoma (NCIt: C3058) Glioblastoma (ORDO: ...  136.0  0.298225  0.202862
# ...                                                   ...       ...       ...
# Endometrioid stromal sarcoma (NCIt: C8973) Endo...    8.0  0.469488  0.105013
# Endometrial carcinoma (NCIt: C7558)                   8.0  0.328019  0.131720
# Endometrial adenosquamous carcinoma (NCIt: C114...    8.0  0.432758  0.186271
# Down syndrome (NCIt: C2993) Myeloid leukemia as...    8.0  0.636736  0.233647
# Uterine corpus sarcoma (NCIt: C6339) Sarcoma of...    8.0  0.572000  0.110034
#
# ...

# %%
# cell = "ACH-000935"
cell = "ACH-000011"

# %%
cell_line = pd.read_html(f"https://www.cellosaurus.org/search?query={cell}")[0][0][0]
cell_line
# Out:
# 'CVCL_7935'

# %%
df = pd.read_html(f"https://www.cellosaurus.org/{cell_line}")

# %%
df
# Out:
# [                                      0  \
#  0                        Cell line name
#  1                              Synonyms
#  2                             Accession
#  3                   Secondary accession
#  4    Resource Identification Initiative
#  5                              Comments
#  6                            HLA typing
#  7                               Disease
#  8                     Species of origin
#  9                             Hierarchy
#  10                          Sex of cell
#  11                      Age at sampling
#  12                             Category
#  13                          STR profile
#  14                            Web pages
#  15                         Publications
#  16                     Cross-references
#  17    Cell line collections (Providers)
#  18        Cell line databases/resources
#  19          Anatomy/cell type resources
#  20          Biological sample resources
#  21                  Chemistry resources
# ...

# %%
race_df = [x for x in df if True in (x == "African").any().unique()]
meta_df = [x for x in df if True in (x == "Cell line name").any().unique()]

print(len(race_df))

r_df = race_df[0]
m_df = meta_df[0]
# Out:
# 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/w_/tv9kwn955c59q5gycbr00lzh0000gn/T/ipykernel_47686/2746456414.py in <module>
#       4 print(len(race_df))
#       5
# ----> 6 r_df = race_df[0]
#       7 m_df = meta_df[0]
#
# IndexError: list index out of range

# %%
m_df
# Out:
#                                       0  \
# 0                        Cell line name
# 1                              Synonyms
# 2                             Accession
# 3    Resource Identification Initiative
# 4                              Comments
# 5                   Sequence variations
# 6                            HLA typing
# 7                       Genome ancestry
# 8                               Disease
# 9                     Species of origin
# 10                             Category
# 11                          STR profile
# 12                            Web pages
# 13                         Publications
# 14                     Cross-references
# 15    Cell line collections (Providers)
# 16        Cell line databases/resources
# 17          Biological sample resources
# 18           CRISP screens repositories
# 19                  Chemistry resources
# 20               Encyclopedic resources
# 21     Experimental variables resources
# ...

# %%
m_df
# Out:
#                                       0  \
# 0                        Cell line name
# 1                              Synonyms
# 2                             Accession
# 3    Resource Identification Initiative
# 4                              Comments
# 5                   Sequence variations
# 6                            HLA typing
# 7                       Genome ancestry
# 8                               Disease
# 9                     Species of origin
# 10                             Category
# 11                          STR profile
# 12                            Web pages
# 13                         Publications
# 14                     Cross-references
# 15    Cell line collections (Providers)
# 16        Cell line databases/resources
# 17          Biological sample resources
# 18           CRISP screens repositories
# 19                  Chemistry resources
# 20               Encyclopedic resources
# 21     Experimental variables resources
# ...

# %%
print(m_df[m_df[0] == "Sex of cell"])

disease = m_df[m_df[0] == "Disease"].iloc[0][1]
sex = m_df[m_df[0] == "Sex of cell"].iloc[0][1]

m_df[m_df[0] == "Age at sampling"]

if not re.findall(r"\d+", (m_df[m_df[0] == "Age at sampling"].iloc[0][1])):
    age = np.nan

else:
    age = int(re.findall(r"\d+", (m_df[m_df[0] == "Age at sampling"].iloc[0][1]))[0])
    

metadata["cell"].append(cell)
metadata["disease"].append(disease)
metadata["sex"].append(sex)
metadata["age"].append(age)

for r in races:
    percent = r_df.pivot_table(columns="Origin", values="% genome")[r][0]
    metadata[r].append(percent)
# Out:
# Empty DataFrame
# Columns: [0, 1]
# Index: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/w_/tv9kwn955c59q5gycbr00lzh0000gn/T/ipykernel_47686/1304287713.py in <module>
#       2
#       3 disease = m_df[m_df[0] == "Disease"].iloc[0][1]
# ----> 4 sex = m_df[m_df[0] == "Sex of cell"].iloc[0][1]
#       5
#       6 m_df[m_df[0] == "Age at sampling"]
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1623
#    1624             # validate the location
# ...

# %%
r_df.pivot_table(columns="Origin", values="% genome")["African"][0]
# Out:
# 1.71

# %%
for k in races:
    print(df[4].pivot_table(columns="Origin", values="% genome")[k][0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/w_/tv9kwn955c59q5gycbr00lzh0000gn/T/ipykernel_47686/761051328.py in <module>
#       1 for k in races:
# ----> 2     print(df[4].pivot_table(columns="Origin", values="% genome")[k][0])
#
# IndexError: list index out of range
